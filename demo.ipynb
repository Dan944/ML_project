# %% [markdown]
# # Libraries

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import torch
import os
import glob
from IPython.display import Image, display

print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Setup complete. Using torch 1.10.0+cu111 (Tesla P100-PCIE-16GB)

# %%
# cd to your own path
# %cd /content/drive/MyDrive/cwks/ml/project/yolov5-face-mask-detection-master/yolov5
# Out:
# /content/drive/MyDrive/cwks/ml/project/yolov5-face-mask-detection-master/yolov5

# %% [markdown]
# # Inference

# %%
# !python detect.py --source demo/ --weights weight/best.pt --conf 0.6
# Out:
# detect: weights=['weight/best.pt'], source=demo/, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.6, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-135-g7926afc torch 1.10.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7018216 parameters, 0 gradients
# image 1/6 /content/drive/MyDrive/cwks/ml/project/yolov5-face-mask-detection-master/yolov5/demo/demo1.jpg: 640x480 1 without_mask, Done. (0.010s)
# image 2/6 /content/drive/MyDrive/cwks/ml/project/yolov5-face-mask-detection-master/yolov5/demo/demo2.jpg: 480x640 1 with_mask, 1 mask_weared_incorrect, Done. (0.011s)
# ...

# %%
#display inference on some test images
images = glob.glob('runs/detect/exp/*.jpg')

for imageName in images[:6]: #assuming JPG
    display(Image(filename=imageName, width=400))
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# # Val

# %%
# !python val.py --weights weight/best.pt --data ../mask_config.yaml --img 640 --iou 0.65 --half
# Out:
# val: data=../mask_config.yaml, weights=['weight/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.65, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=True, dnn=False
# YOLOv5 🚀 v6.1-135-g7926afc torch 1.10.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7018216 parameters, 0 gradients
# val: Scanning '/content/drive/MyDrive/cwks/ml/project/yolov5-face-mask-detection-master/datasets/mask/valid/labels.cache' images and labels... 171 found, 0 missing, 0 empty, 0 corrupt: 100% 171/171 [00:00<?, ?it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:06<00:00,  1.10s/it]
#                  all        171        754      0.717      0.823      0.808      0.524
# ...

# %% [markdown]
# # Train

# %% [markdown]
# If you wanna freeze, please train with freeze first, then train based on the weights you obtained.

# %%
# !python train.py --img 640 --batch 16 --epochs 100 --data ../mask_config.yaml --weights yolov5s.pt --freeze 10 --workers 0
# !python train.py --img 640 --batch 16 --epochs 100 --data ../mask_config.yaml --weights yolov5s.pt --workers 0
